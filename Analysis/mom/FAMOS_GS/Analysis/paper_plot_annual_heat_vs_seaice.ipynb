# %%
# %matplotlib notebook
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly as py
import plotly.graph_objs as go
import ipywidgets as widgets
import seaborn as sns
import colorlover as cl

py.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
fname0 = '../../../../../Analysis/mom/FAMOS_GS/Analysis/data/ITU-MOM/ITU-MOM_GSexps_1980_2009.nc'
ds0 = xr.open_mfdataset(fname0)

fname1 = '../../../../../Analysis/mom/FAMOS_GS/Analysis/data/MITB500/MIT_MITB500_1980_2009.nc'
ds1 = xr.open_mfdataset(fname1)

fname2 = '../../../../../Analysis/mom/FAMOS_GS/Analysis/data/Brest/Brest_GSexps_1980_2009.nc'
ds2 = xr.open_mfdataset(fname2)

fname3 = '../../../../../Analysis/mom/FAMOS_GS/Analysis/data/NorESM/NorESM_GS_experiments_1980_2009.nc'
ds3 = xr.open_mfdataset(fname3)

fname4 = '../../../../../Analysis/mom/FAMOS_GS/Analysis/data/FESOM/FESOM_GS_exps_1980_2009.nc'
ds4 = xr.open_mfdataset(fname4)

# %%
dates0 = pd.date_range('1980-01', freq='M', periods=12*29)
ds0['time'] = dates0
ds1['time'] = dates0
ds2['time'] = dates0
ds3['time'] = dates0
ds4['time'] = dates0

# %%
""" Plot annual heat vs sea ice extent anomaly"""
modelnames = ['ITU' , 'MITB500', 'Brest', 'NorESM', 'FESOM']
#colors = ['blue', 'darkorange', 'red', 'green', 'cyan']
colors = cl.scales['5']['qual']['Dark2']; 

def plot_bso_inflow_heat_seaice(models):
    
    datap = []
    datan = []
    layout = go.Layout(
    title='<b>Annual inflow heat transport vs annual sea ice extent anomaly @BSO</b>',
        yaxis=dict(
            title='$\\text{Sea ice extent } [10^{-9} m^3]$',
            #range=[-14, 14]
        ),
        xaxis=dict(
            title='Heat transport [TW]'
        )
    )  
    # names of the control, gsp and gsn variables [total]  
    ctln = ['ctlxice_barents', 'SIextBK_c', 'refice_extent_BSKS', 'ice_extent_NorESM_BarentsKara_ctrl', 'ctliext_BK']
    gspn = ['gspxice_barents', 'SIextBK_gsp', 'gspice_extent_BSKS', 'ice_extent_NorESM_BarentsKara_gsp', 'gspiext_BK']
    gsnn = ['gsnxice_barents', 'SIextBK_gsm', 'gsnice_extent_BSKS', 'ice_extent_NorESM_BarentsKara_gsn', 'gsniext_BK']

    ctlhn = ['ctlbarents_heatinflow', 'barht_c[1]', 'BSOrefheat_in', 'inflow_ht_NorESM_BSO_ctrl', 'ctlheattransp_BSO_in']
    gsphn = ['gspbarents_heatinflow', 'barht_gsp[1]', 'BSOgspheat_in', 'inflow_ht_NorESM_BSO_gsp', 'gspheattransp_BSO_in']
    gsnhn = ['gsnbarents_heatinflow', 'barht_gsm[1]', 'BSOgsnheat_in', 'inflow_ht_NorESM_BSO_gsn', 'gsnheattransp_BSO_in']

    coeffs = [1e-9, 1e-9, 1e-9, 1e-9, 1e-9]
    for ind,mdl in enumerate(models):
        dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean().year'
        time = np.copy(eval(dnm))
        dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
        dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
        dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
        val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind]) #/(np.copy(eval(dnm))*coeffs[ind])
        val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind]) #/(np.copy(eval(dnm))*coeffs[ind])
        dnm = 'ds'+np.str(ind)+'.'+ctlhn[ind]+'.groupby(\'time.year\').mean()'
        dnm2 = 'ds'+np.str(ind)+'.'+gsphn[ind]+'.groupby(\'time.year\').mean()'
        dnm3 = 'ds'+np.str(ind)+'.'+gsnhn[ind]+'.groupby(\'time.year\').mean()'
        val3 = np.copy(eval(dnm2)-eval(dnm))
        val4 = np.copy(eval(dnm3)-eval(dnm))
        trace1 = go.Scatter(            
            x = val3,
            y = val1,
            mode = 'lines',
            name = mdl+'-GSP',
            line = dict(
                width = 2.5,
                color = colors[ind],
                dash = 'dot',
                shape = 'smooth'
            )
        )
        datap.append(trace1)
        trace2 = go.Scatter(            
            x = val4,
            y = val2,
            mode = 'lines',
            name = mdl+'-GSM',
            line = dict(
                width = 2.5,
                color = colors[ind],
                dash = 'dashdot',
                shape = 'smooth'
            )
        )
        datan.append(trace2)


   
    data = datap + datan
    
    fig = go.Figure(data=data, layout=layout)
    py.offline.iplot(fig)
    


plot_bso_inflow_heat_seaice(modelnames)



#models = widgets.SelectMultiple(options=list(modelnames), value=modelnames, description='Models')    
#widgets.interactive(update_plot,models=models)
# Out:
# <div id="e4009753-0b9c-4fe3-9473-fb4441743202" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e4009753-0b9c-4fe3-9473-fb4441743202", [{"name": "ITU-GSP", "mode": "lines", "y": [-13.370512725333253, -27.308752896, -38.98963012266675, -42.26472846933338, -33.845783552, -57.024413696, -62.09788313600001, -77.22153847466676, -77.138444288, -52.386884266666755, -55.09326711466675, -57.53677687466675, -63.96766071466675, -33.69576994133325, -51.89929617066675, -61.00884138666675, -58.84285542400001, -37.19665629866675, -33.09419451733326, -27.599056213333252, -39.502371498666626, -37.51393962666675, -49.10988765866675, -30.889334101333255, -29.938084522666628, -16.727262378666627, -33.88788565333338, -37.44214267733325, -49.0800756053335], "x": [3.1950493308944736, 4.591455604327834, 5.558717911877338, 6.01609491517879, 4.004075758019233, 6.760401451915307, 6.56296440972439, 6.097760753563829, 9.01400077436847, 7.8513289803618065, 6.859354140635588, 8.87380832634738, 7.377100
ht_NorESM_BSO_ctrl', 'ctlheattransp_BSO_in']
    gsphn = ['gspbarents_heatinflow', 'barht_gsp[1]', 'BSOgspheat_in', 'inflow_ht_NorESM_BSO_gsp', 'gspheattransp_BSO_in']
    gsnhn = ['gsnbarents_heatinflow', 'barht_gsm[1]', 'BSOgsnheat_in', 'inflow_ht_NorESM_BSO_gsn', 'gsnheattransp_BSO_in']

    coeffs = [1e-9, 1e-9, 1e-9, 1e-9, 1e-9]
    for ind,mdl in enumerate(models):
        dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean().year'
        time = np.copy(eval(dnm))
        dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'[ds'+np.str(ind)+'[\'time.month\']=='+mnth+']'
        dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'[ds'+np.str(ind)+'[\'time.month\']=='+mnth+']'        
        dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'[ds'+np.str(ind)+'[\'time.month\']=='+mnth+']'
        val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind]) #/(np.copy(eval(dnm))*coeffs[ind])
        val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind]) #/(np.copy(eval(dnm))*coeffs[ind])
        dnm = 'ds'+np.str(ind)+'.'+ctlhn[ind]+'.groupby(\'time.year\').mean()'
        dnm2 = 'ds'+np.str(ind)+'.'+gsphn[ind]+'.groupby(\'time.year\').mean()'
        dnm3 = 'ds'+np.str(ind)+'.'+gsnhn[ind]+'.groupby(\'time.year\').mean()'
        val3 = np.copy(eval(dnm2)-eval(dnm))
        val4 = np.copy(eval(dnm3)-eval(dnm))
        trace1 = go.Scatter(            
            x = val3,
            y = val1,
            mode = 'lines',
            name = mdl+'-GSP',
            line = dict(
                width = 2.5,
                color = colors[ind],
                dash = 'dot',
                shape = 'smooth'
            )
        )
        datap.append(trace1)
        trace2 = go.Scatter(            
            x = val4,
            y = val2,
            mode = 'lines',
            name = mdl+'-GSM',
            line = dict(
                width = 2.5,
                color = colors[ind],
                dash = 'dashdot',
                shape = 'smooth'
            )
        )
        datan.append(trace2)


   
    data = datap + datan
    
    fig = go.Figure(data=data, layout=layout)
    py.offline.iplot(fig)
    


plot_bso_inflow_heat_seaice(modelnames)



#models = widgets.SelectMultiple(options=list(modelnames), value=modelnames, description='Models')    
#widgets.interactive(update_plot,models=models)
# Out:
# <div id="3e1f0a35-b47f-4ca6-9f88-74333ea93b3a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3e1f0a35-b47f-4ca6-9f88-74333ea93b3a", [{"name": "ITU-GSP", "mode": "lines", "y": [-7.018119168, -12.897746944000001, -24.727519232000002, -77.19931084800001, -20.85486592, -44.724649984, -75.37347788800001, -103.455653888, -73.332948992, -51.216121856, -58.943602688000006, -37.49183488, -76.867436544, -15.277752320000001, -56.203149312, -61.812768768000005, -75.88518297600001, -39.94550272, -19.234553856, -28.493479936000004, -48.010100736000005, -39.703281664, -34.072690688, -60.351840256, -55.674929152000004, -26.416775168, -37.305188352, -34.505883648, -55.315529728], "x": [3.1950493308944736, 4.591455604327834, 5.558717911877338, 6.01609491517879, 4.004075758019233, 6.760401451915307, 6.56296440972439, 6.097760753563829, 9.01400077436847, 7.8513289803618065, 6.859354140635588, 8.87380832634738, 7.377100359225828, 7.09316599387342, 5.359961479503731, 5.400254102542142, 5.8487653888898805, 4.033461806459378, 5.326565911289464, 5.602223208205842, 4.298101226358135, 4.263075385164456, 1.836628864629219, 3.6505526160554496, 7.666834699766817, 7.2188126607580685, 7.182708871013077, 5.950289289243059, 9.36199317802609], "line": {"dash": "dot", "color": "rgb(27,158,119)", "shape": "smooth", "width": 2.5}, "type": "scatter"}, {"name": "MITB500-GSP", "mode": "lines", "y": [-17.093754880000002, -45.311197184, -73.66967296, -56.141152256000005, -78.36860416, -108.599443456, -79.51692595200001, -84.430159872, -83.22809856, -85.68229068800001, -105.65687705600001, -75.35460352, -42.484891648, -51.042713600000006, -32.865517568, -18.28913152, -56.173264896000006, -69.582061568, -47.802089472000006, -33.950400512, -64.22790144000001, -63.01745152, -34.142158848, -77.049102336, -129.794572288, -104.37001216, -116.58474291200001, -96.790249472, -75.10268313600001], "x": [5.285113652547196, 7.155331611633301, 6.954321702321366, 11.023972193400063, 11.53881231943766, 8.175420443216957, 14.312751293182366, 10.707844416300453, 13.713486989339195, 16.10633818308513, 10.33194351196289, 7.865870793660477, 6.661986351013184, 2.7145353953043667, 4.753877321879067, 3.4696524937947615, 6.422813097635903, 8.507033665974937, 6.996204376220703, 15.724901517232254, 16.11421489715576, 12.409317016601562, 12.879574457804367, 16.065872192382812, 22.410347302754722, 23.343130111694336, 16.82674916585286, 15.167669614156097, 16.438373883565262], "line": {"dash": "dot", "color": "rgb(217,95,2)", "shape": "smooth", "width": 2.5}, "type": "scatter"}, {"name": "Brest-GSP", "mode": "lines", "y": [-9.27308177947998, -14.208728790283203, -24.54454231262207, -47.53089904785156, -55.786338806152344, -65.16690063476562, -34.873016357421875, -26.176651000976562, -50.34920883178711, -46.2901725769043, -50.001346588134766, -26.98261260986328, -28.720233917236328, -28.358213424682617, -43.04325866699219, -27.561033248901367, -49.435245513916016, -5.994970798492432, -32.81570816040039, -14.892399787902832, -25.075252532958984, -26.479427337646484, -32.205177307128906, -52.35198974609375, -65.78450775146484, -22.390243530273438, -20.13056182861328, -18.18021011352539, -11.336023330688477], "x": [5.317295074462891, 7.523654937744141, 6.3246002197265625, 8.202651977539062, 8.63699722290039, 8.350082397460938, 7.375934600830078, 7.376747131347656, 9.939098358154297, 12.264663696289062, 8.311668395996094, 4.926200866699219, 6.694183349609375, 6.48077392578125, 6.035121917724609, 3.7487220764160156, 3.8504867553710938, 7.8206787109375, 7.946430206298828, 8.199874877929688, 7.541893005371094, 6.535587310791016, 7.327327728271484, 9.231800079345703, 10.337627410888672, 4.693489074707031, 4.301788330078125, 10.093681335449219, 9.883613586425781], "line": {"dash": "dot", "color": "rgb(117,112,179)", "shap ...

# %%
""" Plot March heat vs sea ice extent anomaly"""
modelnames = ['ITU' , 'MITB500', 'Brest', 'NorESM', 'FESOM']
#colors = ['blue', 'darkorange', 'red', 'green', 'cyan']
colors = cl.scales['5']['qual']['Dark2']; 
mnth = np.str(9) # September

def plot_bso_inflow_heat_seaice(models):
    
    datap = []
    datan = []
    layout = go.Layout(
    title='<b>Annual inflow heat transport vs September sea ice extent anomaly @BSO</b>',
        yaxis=dict(
            title='$\\text{Sea ice extent } [10^{-9} m^3]$',
            #range=[-14, 14]
        ),
        xaxis=dict(
            title='Heat transport [TW]'
        )
    )  
    # names of the control, gsp and gsn variables [total]  
    ctln = ['ctlxice_barents', 'SIextBK_c', 'refice_extent_BSKS', 'ice_extent_NorESM_BarentsKara_ctrl', 'ctliext_BK']
    gspn = ['gspxice_barents', 'SIextBK_gsp', 'gspice_extent_BSKS', 'ice_extent_NorESM_BarentsKara_gsp', 'gspiext_BK']
    gsnn = ['gsnxice_barents', 'SIextBK_gsm', 'gsnice_extent_BSKS', 'ice_extent_NorESM_BarentsKara_gsn', 'gsniext_BK']

    ctlhn = ['ctlbarents_heatinflow', 'barht_c[1]', 'BSOrefheat_in', 'inflow_ht_NorESM_BSO_ctrl', 'ctlheattransp_BSO_in']
    gsphn = ['gspbarents_heatinflow', 'barht_gsp[1]', 'BSOgspheat_in', 'inflow_ht_NorESM_BSO_gsp', 'gspheattransp_BSO_in']
    gsnhn = ['gsnbarents_heatinflow', 'barht_gsm[1]', 'BSOgsnheat_in', 'inflow_ht_NorESM_BSO_gsn', 'gsnheattransp_BSO_in']

    coeffs = [1e-9, 1e-9, 1e-9, 1e-9, 1e-9]
    for ind,mdl in enumerate(models):
        dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean().year'
        time = np.copy(eval(dnm))
        dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'[ds'+np.str(ind)+'[\'time.month\']=='+mnth+']'
        dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'[ds'+np.str(ind)+'[\'time.month\']=='+mnth+']'        
        dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'[ds'+np.str(ind)+'[\'time.month\']=='+mnth+']'
        val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind]) #/(np.copy(eval(dnm))*coeffs[ind])
        val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind]) #/(np.copy(eval(dnm))*coeffs[ind])
        dnm = 'ds'+np.str(ind)+'.'+ctlhn[ind]+'.groupby(\'time.year\').mean()'
        dnm2 = 'ds'+np.str(ind)+'.'+gsphn[ind]+'.groupby(\'time.year\').mean()'
        dnm3 = 'ds'+np.str(ind)+'.'+gsnhn[ind]+'.groupby(\'time.year\').mean()'
        val3 = np.copy(eval(dnm2)-eval(dnm))
        val4 = np.copy(eval(dnm3)-eval(dnm))
        trace1 = go.Scatter(            
            x = val3,
            y = val1,
            mode = 'lines',
            name = mdl+'-GSP',
            line = dict(
                width = 2.5,
                color = colors[ind],
                dash = 'dot',
                shape = 'smooth'
            )
        )
        datap.append(trace1)
        trace2 = go.Scatter(            
            x = val4,
            y = val2,
            mode = 'lines',
            name = mdl+'-GSM',
            line = dict(
                width = 2.5,
                color = colors[ind],
                dash = 'dashdot',
                shape = 'smooth'
            )
        )
        datan.append(trace2)


   
    data = datap + datan
    
    fig = go.Figure(data=data, layout=layout)
    py.offline.iplot(fig)
    


plot_bso_inflow_heat_seaice(modelnames)



#models = widgets.SelectMultiple(options=list(modelnames), value=modelnames, description='Models')    
#widgets.interactive(update_plot,models=models)
# Out:
# <div id="178c4d57-823f-47f8-80c9-ae5779daad74" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot